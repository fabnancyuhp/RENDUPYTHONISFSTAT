# %% [markdown]
# <a href="https://colab.research.google.com/github/fabnancyuhp/RENDUPYTHONISFSTAT/blob/master/KMEANS_ET_CAH_LEGROS_Adrien.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algorithmes pour réduire les dimentions des données
# * TSNE : t-distributed Stochastic Neighbor Embedding. t-SNE is a tool to visualize high-dimensional data. It converts similarities between data points to joint probabilities and tries to minimize the Kullback-Leibler divergence between the joint probabilities of the low-dimensional embedding and the high-dimensional data.
# * LocallyLinearEmbedding : Locally linear embedding (LLE) seeks a lower-dimensional projection of the data which preserves distances within local neighborhoods. It can be thought of as a series of local Principal Component Analyses which are globally compared to find the best non-linear embedding.
# * PCA : Principal component analysis. Linear dimensionality reduction using Singular Value Decomposition of the data to project it to a lower dimensional space. The input data is centered but not scaled for each feature before applying the SVD. We use PCA for dense data.
# * TruncatedSVD : This transformer performs linear dimensionality reduction by means of truncated singular value decomposition (SVD). Contrary to PCA, this estimator does not center the data before computing the singular value decomposition. This means it can work with scipy.sparse matrices efficiently. We use TruncatedSVD to reduce the number of dimensions to a reasonable amount (e.g. 50) if the number of features is very high.

# %% [markdown]
# Quelques remarques:
# * T-SNE aide à la visualisation des données. T-SNE ne conserve pas les distances. Il ne faut donc pas appliquer un alogrithme de kmeans ou une CAH sur les sorties ce dernier.
# * Si l'on veut un algorithme de réduction des données qui préserve les distances, on peut utiliser l'algorithme PCA
# * TruncatedSVD s'utilise dans le contexte du text mining dans le cadre de donnée sparse/creuse

# %% [markdown]
# # Algorithmes de clustering vues dans ce chapitre
# Dans ce chapitre on applique l'algorithme du Kmeans et celui de la classification ascendante hiérarchique.  Ces derniers des sont algorithmes non supervisé. On veut découvrire des pattern/formes. On admet que ces algorithmes ont été vu dans le cadre de cours plus théorique. Voici les liens wikipédia:
# * https://en.wikipedia.org/wiki/K-means_clustering
# * https://fr.wikipedia.org/wiki/Regroupement_hi%C3%A9rarchique

# %% [markdown]
# # Application de l'algorithmes kmeans et CAH sur les données digit
# Les données digit sont accessibles via le package sklearn.datasets. L'objet X représente les données digits. Il y 1797 lignes. Chaques lignes à 64 colonnes. Un chiffre est donc représenté par ces 64 colonnes. Nous avons donc 10 classes dans ce jeux de données. L'objet Y représente les classes des données. On utilise ces derniers à tire indicatif.

# %% [markdown]
# On charge les données digits:

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.data
print(X.shape)
print(type(X))
X
# Out:
# (1797, 64)
# <class 'numpy.ndarray'>
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %% [markdown]
# On charge les classes:

# %%
Y = digits.target
Y.shape
from collections import Counter
Counter(Y)
# Out:
# Counter({0: 178,
#          1: 182,
#          2: 177,
#          3: 183,
#          4: 181,
#          5: 182,
#          6: 181,
#          7: 179,
#          8: 174,
#          9: 180})

# %% [markdown]
# ## On commence par représenter les données graphiquement avec un TSNE
# On réduit les dimensions à l'aide du TSNE avant la représentation graphique : on passe de 64 colonnes à 2 colonnes.

# %%
from sklearn.manifold import TSNE
t_sne = TSNE(n_components=2,random_state=1998)

X_proj = t_sne.fit_transform(X)
X_proj[0:2]
# Out:
# array([[ 16.781614, -66.73827 ],
#        [-10.757889,  22.564926]], dtype=float32)

# %%
X_proj.shape
# Out:
# (1797, 2)

# %% [markdown]
# On peut faire la representation:

# %%
import matplotlib.pyplot as plt
plt.scatter(X_proj[:,0][Y==0],X_proj[:,1][Y==0],color='black',alpha=6/11,label='0')
plt.scatter(X_proj[:,0][Y==1],X_proj[:,1][Y==1],color='blue',alpha=6/11,label='1')
plt.scatter(X_proj[:,0][Y==2],X_proj[:,1][Y==2],color='red',alpha=6/11,label='2')
plt.scatter(X_proj[:,0][Y==3],X_proj[:,1][Y==3],color='grey',alpha=6/11,label='3')
plt.scatter(X_proj[:,0][Y==4],X_proj[:,1][Y==4],color='aquamarine',alpha=6/11,label='4')
plt.scatter(X_proj[:,0][Y==5],X_proj[:,1][Y==5],color='pink',alpha=6/11,label='5')
plt.scatter(X_proj[:,0][Y==6],X_proj[:,1][Y==6],color='yellow',alpha=6/11,label='6')
plt.scatter(X_proj[:,0][Y==7],X_proj[:,1][Y==7],color='navy',alpha=6/11,label='7')
plt.scatter(X_proj[:,0][Y==8],X_proj[:,1][Y==8],color='green',alpha=6/11,label='8')
plt.scatter(X_proj[:,0][Y==9],X_proj[:,1][Y==9],color='orange',alpha=6/11,label='9')
plt.legend(loc=3)
#for i in range(0,len(Y)):
    #plt.text(X_proj[i,0],X_proj[i,1],str(Y[i]))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(X_proj[:, 0], X_proj[:, 1], lw=0.1,
            c=digits.target, cmap=plt.cm.get_cmap('cubehelix', 10))
plt.colorbar(ticks=range(10), label='digit value')

# %% [markdown]
# ## On fait un algorithme du K_means sur les données digit
# On fait un k_means à 10 classes donc 10 centroides.

# %%
from sklearn.cluster import KMeans

kmean = KMeans(n_clusters=10,max_iter=20000,n_init=1000)
kmean.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=20000,
#     n_clusters=10, n_init=1000, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# On regarde dans quel cluster sont les élément de X en utilisant fit_predict:

# %%
kmean.fit_predict(X)

# %% [markdown]
# Les centres des clusters sont:

# %%
centre = kmean.cluster_centers_
centre.view()
# Out:
# array([[ 0.00000000e+00,  1.11564626e+00,  1.00408163e+01,
#          1.34081633e+01,  1.41972789e+01,  1.26598639e+01,
#          4.43537415e+00,  4.08163265e-02,  6.80272109e-03,
#          4.57823129e+00,  1.49319728e+01,  1.26666667e+01,
#          8.72789116e+00,  6.94557823e+00,  2.48299320e+00,
#          3.40136054e-02,  1.36054422e-02,  6.05442177e+00,
#          1.45442177e+01,  6.03401361e+00,  1.97278912e+00,
#          8.43537415e-01,  1.22448980e-01,  1.38777878e-16,
#          6.80272109e-03,  5.32653061e+00,  1.43265306e+01,
#          1.23673469e+01,  7.75510204e+00,  2.13605442e+00,
#          1.42857143e-01, -5.20417043e-18,  0.00000000e+00,
#          1.97278912e+00,  8.23129252e+00,  1.01156463e+01,
#          1.02925170e+01,  5.54421769e+00,  6.46258503e-01,
#          0.00000000e+00, -2.08166817e-17,  3.06122449e-01,
#          1.41496599e+00,  4.91156463e+00,  9.80952381e+00,
#          7.10204082e+00,  7.89115646e-01, -8.32667268e-17,
#         -1.90819582e-17,  8.16326531e-01,  5.12925170e+00,
#          9.57142857e+00,  1.21156463e+01,  5.30612245e+00,
#          4.48979592e-01, -3.88578059e-16, -1.30104261e-18,
#          1.06802721e+00,  1.09455782e+01,  1.45442177e+01,
#          7.76190476e+00,  1.07482993e+00,  2.04081633e-02,
#         -6.10622664e-16],
#        [ 0.00000000e+00,  5.88888889e-01,  8.68333333e+00,
#          1.45444444e+01,  1.40222222e+01,  7.04444444e+00,
#          6.22222222e-01, -2.77555756e-16,  1.11111111e-02,
#          4.16111111e+00,  1.26444444e+01,  9.18333333e+00,
#          1.12666667e+01,  1.20388889e+01,  1.88333333e+00,
#          1.11111111e-02,  5.55555556e-03,  1.89444444e+00,
#          3.79444444e+00,  3.70555556e+00,  1.18000000e+01,
#          9.93333333e+00,  8.55555556e-01,  5.55111512e-17,
#         -2.81892565e-18,  6.11111111e-02,  9.77777778e-01,
#          8.22222222e+00,  1.38222222e+01,  6.84444444e+00,
#          3.27777778e-01, -5.63785130e-18,  0.00000000e+00,
#          6.11111111e-02,  6.72222222e-01,  4.55555556e+00,
#          1.16833333e+01,  1.22777778e+01,  2.31111111e+00,
#          0.00000000e+00, -2.25514052e-17,  4.61111111e-01,
#          1.48888889e+00,  6.83333333e-01,  4.18333333e+00,
#          1.24166667e+01,  6.27777778e+00,  5.55555556e-03,
#         -2.42861287e-17,  9.38888889e-01,  7.37777778e+00,
#          6.62222222e+00,  8.62777778e+00,  1.36555556e+01,
#          6.05000000e+00,  1.72222222e-01, -1.40946282e-18,
#          4.66666667e-01,  9.46666667e+00,  1.49166667e+01,
#          1.41000000e+01,  8.85000000e+00,  1.85555556e+00,
#          4.11111111e-01],
#        [ 0.00000000e+00,  1.11111111e-01,  3.99555556e+00,
#          1.18844444e+01,  1.23688889e+01,  5.36888889e+00,
#          4.31111111e-01, -3.33066907e-16,  8.88888889e-03,
#          8.62222222e-01,  8.27555556e+00,  1.35511111e+01,
#          1.26222222e+01,  9.89333333e+00,  1.56000000e+00,
#          4.44089210e-16, -1.51788304e-17,  1.21333333e+00,
#          8.36444444e+00,  1.18755556e+01,  1.22577778e+01,
#          9.48000000e+00,  1.04000000e+00, -9.71445147e-17,
#         -3.25260652e-18,  9.37777778e-01,  7.20000000e+00,
#          1.40977778e+01,  1.41644444e+01,  4.97777778e+00,
#          2.08888889e-01, -6.50521303e-18,  0.00000000e+00,
#          7.64444444e-01,  7.97333333e+00,  1.47866667e+01,
#          1.29288889e+01,  2.21333333e+00,  1.77777778e-02,
#          0.00000000e+00, -2.60208521e-17,  1.23555556e+00,
#          1.05244444e+01,  1.19733333e+01,  1.21111111e+01,
#          4.13333333e+00,  2.13333333e-01,  3.46944695e-17,
#          1.33333333e-02,  8.75555556e-01,  9.62666667e+00,
#          1.14933333e+01,  1.20355556e+01,  5.69333333e+00,
#          6.62222222e-01,  4.44444444e-03,  4.44444444e-03,
#          1.11111111e-01,  4.20888889e+00,  1.20222222e+01,
#          1.26711111e+01,  4.91111111e+00,  8.08888889e-01,
#          8.88888889e-03],
#        [ 0.00000000e+00,  1.58653846e-01,  4.92307692e+00,
#          1.29471154e+01,  1.39663462e+01,  1.07644231e+01,
#          4.85096154e+00,  9.23076923e-01, -2.86229374e-17,
#          1.12019231e+00,  1.07788462e+01,  1.15096154e+01,
#          1.03557692e+01,  1.25528846e+01,  5.39423077e+00,
#          5.28846154e-01, -1.43114687e-17,  1.22115385e+00,
#          5.62980769e+00,  2.29326923e+00,  6.85576923e+00,
#          1.16057692e+01,  3.34134615e+00,  1.10576923e-01,
#         -3.25260652e-18,  1.00961538e+00,  5.17307692e+00,
#          6.50000000e+00,  1.22259615e+01,  1.20144231e+01,
#          4.69711538e+00,  4.80769231e-03,  0.00000000e+00,
#          1.44230769e+00,  8.54807692e+00,  1.29230769e+01,
#          1.46875000e+01,  1.05576923e+01,  3.87980769e+00,
#          0.00000000e+00, -2.60208521e-17,  1.10576923e+00,
#          5.08653846e+00,  1.15240385e+01,  1.10480769e+01,
#          3.59134615e+00,  5.28846154e-01,  1.73472348e-17,
#         -2.68882139e-17,  1.00961538e-01,  2.99038462e+00,
#          1.23509615e+01,  6.37980769e+00,  4.37500000e-01,
#          1.44230769e-02, -6.10622664e-16, -1.62630326e-18,
#          1.25000000e-01,  6.11057692e+00,  1.20913462e+01,
#          2.68269231e+00,  3.12500000e-01,  3.36538462e-02,
#         -7.21644966e-16],
#        [ 0.00000000e+00, -9.99200722e-16,  2.90909091e-01,
#          7.11515152e+00,  1.19818182e+01,  1.94545455e+00,
#          1.51515152e-01,  5.45454545e-02, -2.25514052e-17,
#          1.21212121e-02,  3.24848485e+00,  1.38000000e+01,
#          8.50909091e+00,  1.50303030e+00,  9.27272727e-01,
#          2.78787879e-01, -1.12757026e-17,  6.30303030e-01,
#          1.06787879e+01,  1.16121212e+01,  4.32727273e+00,
#          5.20000000e+00,  3.86666667e+00,  3.27272727e-01,
#          6.06060606e-03,  4.74545455e+00,  1.47575758e+01,
#          5.89090909e+00,  6.83636364e+00,  1.07636364e+01,
#          6.22424242e+00,  1.81818182e-02,  0.00000000e+00,
#          8.92121212e+00,  1.48181818e+01,  9.35757576e+00,
#          1.27939394e+01,  1.43878788e+01,  5.47272727e+00,
#          0.00000000e+00,  9.69696970e-02,  6.50303030e+00,
#          1.16606061e+01,  1.23212121e+01,  1.48606061e+01,
#          1.08000000e+01,  1.57575758e+00, -4.51028104e-17,
#          6.06060606e-02,  1.12121212e+00,  3.00000000e+00,
#          7.72727273e+00,  1.41393939e+01,  4.15757576e+00,
#          1.81818182e-02, -4.71844785e-16, -1.40946282e-18,
#          2.42424242e-02,  3.51515152e-01,  7.91515152e+00,
#          1.23818182e+01,  1.78181818e+00, -5.77315973e-15,
#         -6.66133815e-16],
#        [ 0.00000000e+00,  9.48275862e-01,  1.02298851e+01,
#          1.44482759e+01,  7.74712644e+00,  9.77011494e-01,
#         -1.33226763e-15, -2.77555756e-16,  2.29885057e-02,
#          5.27011494e+00,  1.37183908e+01,  1.26206897e+01,
#          1.16724138e+01,  3.18965517e+00,  1.72413793e-02,
#          3.60822483e-16,  1.14942529e-02,  4.58620690e+00,
#          8.12068966e+00,  6.17241379e+00,  1.21839080e+01,
#          3.49425287e+00,  1.72413793e-02,  7.63278329e-17,
#         -2.81892565e-18,  9.71264368e-01,  2.83333333e+00,
#          7.04597701e+00,  1.25344828e+01,  2.54022989e+00,
#          4.02298851e-02, -5.63785130e-18,  0.00000000e+00,
#          4.59770115e-02,  1.58045977e+00,  9.93678161e+00,
#          1.06666667e+01,  1.43678161e+00, -7.10542736e-15,
#          0.00000000e+00, -2.25514052e-17,  2.52873563e-01,
#          4.48275862e+00,  1.12356322e+01,  7.72413793e+00,
#          2.38505747e+00,  8.50574713e-01,  1.14942529e-02,
#         -2.34187669e-17,  1.20114943e+00,  1.10402299e+01,
#          1.37183908e+01,  1.19252874e+01,  1.11781609e+01,
#          7.70689655e+00,  1.10919540e+00, -1.40946282e-18,
#          9.36781609e-01,  1.04310345e+01,  1.44597701e+01,
#          1.35172414e+01,  1.23793103e+01,  9.01724138e+00,
#          2.97126437e+00],
#        [ 0.00000000e+00,  2.00819672e-01,  6.52459016e+00,
#          1.25327869e+01,  1.18278689e+01,  5.63114754e+00,
#          6.31147541e-01,  8.19672131e-03,  4.09836066e-03,
#          2.62704918e+00,  1.39795082e+01,  9.10655738e+00,
#          9.35245902e+00,  1.03360656e+01,  1.29918033e+00,
#          4.09836066e-03, -1.60461922e-17,  4.35245902e+00,
#          1.28278689e+01,  4.31147541e+00,  6.84016393e+00,
#          1.11475410e+01,  1.92213115e+00, -1.38777878e-16,
#         -1.08420217e-18,  2.35245902e+00,  1.05532787e+01,
#          1.18893443e+01,  1.32090164e+01,  1.20983607e+01,
#          2.48360656e+00, -2.16840434e-18,  0.00000000e+00,
#          3.07377049e-01,  3.22950820e+00,  6.18442623e+00,
#          6.68032787e+00,  1.12663934e+01,  4.31147541e+00,
#          0.00000000e+00, -8.67361738e-18,  2.09016393e-01,
#          2.26639344e+00,  1.95901639e+00,  1.65983607e+00,
#          1.08647541e+01,  6.47131148e+00,  1.63934426e-02,
#         -2.94902991e-17,  7.50000000e-01,  8.01639344e+00,
#          5.59016393e+00,  4.69672131e+00,  1.22049180e+01,
#          5.99590164e+00,  1.14754098e-01, -5.42101086e-19,
#          1.72131148e-01,  6.43032787e+00,  1.34836066e+01,
#          1.45163934e+01,  9.96721311e+00,  2.31967213e+00,
#          1.14754098e-01],
#        [ 0.00000000e+00, -1.16573418e-15,  1.15934066e+00,
#          1.12252747e+01,  9.53296703e+00,  1.41758242e+00,
#          5.49450549e-03, -3.05311332e-16, -2.51534904e-17,
#          6.04395604e-02,  7.18131868e+00,  1.45604396e+01,
#          6.19230769e+00,  8.29670330e-01,  2.74725275e-02,
#          3.74700271e-16, -1.25767452e-17,  7.69230769e-01,
#          1.24560440e+01,  9.47252747e+00,  9.34065934e-01,
#          1.09890110e-01,  0.00000000e+00,  4.16333634e-17,
#         -3.03576608e-18,  2.29670330e+00,  1.36208791e+01,
#          8.09340659e+00,  3.87362637e+00,  1.92857143e+00,
#          1.04395604e-01, -6.07153217e-18,  0.00000000e+00,
#          3.52747253e+00,  1.46758242e+01,  1.29175824e+01,
#          1.22527473e+01,  1.02857143e+01,  2.71978022e+00,
#          0.00000000e+00, -2.42861287e-17,  1.86813187e+00,
#          1.45164835e+01,  1.06538462e+01,  5.57692308e+00,
#          1.01923077e+01,  9.13186813e+00,  2.30769231e-01,
#         -2.42861287e-17,  1.75824176e-01,  1.02857143e+01,
#          1.26263736e+01,  5.41758242e+00,  1.13241758e+01,
#          1.08956044e+01,  6.26373626e-01, -1.51788304e-18,
#         -6.10622664e-16,  1.44505495e+00,  1.07362637e+01,
#          1.50989011e+01,  1.31318681e+01,  4.62087912e+00,
#          1.70329670e-01],
#        [ 0.00000000e+00,  2.23463687e-02,  4.22905028e+00,
#          1.31396648e+01,  1.12681564e+01,  2.93854749e+00,
#          3.35195531e-02, -2.77555756e-16, -2.51534904e-17,
#          8.82681564e-01,  1.26201117e+01,  1.33687151e+01,
#          1.14078212e+01,  1.13687151e+01,  9.60893855e-01,
#          3.60822483e-16, -1.25767452e-17,  3.72625698e+00,
#          1.42122905e+01,  5.25139665e+00,  2.10614525e+00,
#          1.21173184e+01,  3.53072626e+00,  5.55111512e-17,
#         -2.81892565e-18,  5.29608939e+00,  1.26424581e+01,
#          2.03351955e+00,  2.29050279e-01,  9.07821229e+00,
#          6.47486034e+00, -5.63785130e-18,  0.00000000e+00,
#          5.88268156e+00,  1.14916201e+01,  8.65921788e-01,
#          3.35195531e-02,  8.81005587e+00,  7.15083799e+00,
#          0.00000000e+00, -2.25514052e-17,  3.51396648e+00,
#          1.32849162e+01,  1.65921788e+00,  1.49162011e+00,
#          1.13519553e+01,  5.84357542e+00, -2.08166817e-17,
#         -2.42861287e-17,  8.04469274e-01,  1.31117318e+01,
#          9.96089385e+00,  1.03519553e+01,  1.32960894e+01,
#          2.47486034e+00,  2.23463687e-02, -1.40946282e-18,
#          5.58659218e-03,  4.19553073e+00,  1.35865922e+01,
#          1.33407821e+01,  5.48044693e+00,  3.18435754e-01,
#          1.67597765e-02],
#        [ 0.00000000e+00,  2.77555756e-16,  3.22580645e-02,
#          1.84946237e+00,  1.10645161e+01,  1.25268817e+01,
#          4.21505376e+00,  2.58064516e-01,  8.67361738e-19,
#          5.37634409e-02,  1.95698925e+00,  8.93548387e+00,
#          1.37741935e+01,  1.24301075e+01,  5.27956989e+00,
#          3.22580645e-01,  4.33680869e-19,  1.56989247e+00,
#          8.66666667e+00,  1.24408602e+01,  1.19032258e+01,
#          1.28387097e+01,  3.98924731e+00,  1.39784946e-01,
#         -1.30104261e-18,  3.55913978e+00,  1.19784946e+01,
#          1.17634409e+01,  1.29354839e+01,  1.35376344e+01,
#          2.61290323e+00, -2.60208521e-18,  0.00000000e+00,
#          1.94623656e+00,  6.87096774e+00,  7.44086022e+00,
#          1.18172043e+01,  1.26021505e+01,  1.89247312e+00,
#          0.00000000e+00, -1.04083409e-17,  7.84946237e-01,
#          2.01075269e+00,  3.77419355e+00,  1.16774194e+01,
#          1.19354839e+01,  1.20430108e+00, -2.08166817e-17,
#         -6.07153217e-18,  6.45161290e-02,  3.11827957e-01,
#          3.02150538e+00,  1.24623656e+01,  1.16021505e+01,
#          1.65591398e+00,  2.77555756e-17, -6.50521303e-19,
#          5.55111512e-16,  6.21724894e-15,  1.96774194e+00,
#          1.13978495e+01,  1.05698925e+01,  1.68817204e+00,
#         -3.88578059e-16]])

# %% [markdown]
# L'inertie de ces 10 classes est:

# %%
kmean.inertia_
# Out:
# 1165122.9269429883

# %% [markdown]
# On représente les données avec leur classes retourné par l'algorithme k_means. On utilise les données projeté avec l'algorithme T_sne:

# %%
Y_pred = kmean.fit_predict(X)

import numpy as np

import matplotlib.pyplot as plt

for o in np.unique(Y_pred):
    plt.scatter(X_proj[:,0][Y_pred==o], X_proj[:, 1][Y_pred==o], label=o,lw=0.1)
plt.legend(loc=3)
plt.show
#plt.colorbar(ticks=range(10), label='digit value')
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## On fait une classification hiérarchique sur les données digit
# 1/Cette classification serat faite sur 10 clusters.

# %%
from sklearn.cluster import AgglomerativeClustering

#on peut utiliser les différent linkage: “ward”, “complete”, “average”, “single”
CAH = AgglomerativeClustering(n_clusters=10, affinity='euclidean',linkage='ward')
clustering = CAH.fit(X) # Entraine
clusteringbis = CAH.fit_predict(X) # Entraine et Prédit

# %% [markdown]
# 2/On affiche les clusters avec clustering.labels_, ou bien clusteringbis:

# %%
print(clustering.labels_)
print(clusteringbis)
np.where((clustering.labels_ == clusteringbis)==False)
# Out:
# [7 9 4 ... 4 1 4]
# [7 9 4 ... 4 1 4]
# (array([], dtype=int64),)

# %% [markdown]
# On représente les clusters avec l'embeding produit par le TSNE:

# %%
Y_pred = clustering.labels_

import numpy as np
import matplotlib.pyplot as plt

for o in np.unique(Y_pred):
    plt.scatter(X_proj[:,0][Y_pred==o], X_proj[:, 1][Y_pred==o], label=o,lw=0.1)
plt.legend(loc=3)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# On peut constater que l'algorithme kmeans detecte correctement les paterns.

# %% [markdown]
# On construit un dendogramme:

# %%
from scipy.cluster import hierarchy
Z = hierarchy.linkage(X, method='ward',metric='euclidean')

plt.figure()
dn = hierarchy.dendrogram(Z)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Régle du coude

# %% [markdown]
# On simule un ensemble de données à trois dimensions. Il y a 3 classes dans cet ensemble.

# %%
import numpy as np
y1 = np.random.normal(loc=2,scale=1,size=400)
y2 = np.random.normal(loc=2,scale=1,size=400)
y3 = np.random.normal(loc=2,scale=1,size=400)
Z1 = np.vstack((y1,y2,y3)).T

y1 = np.random.normal(loc=3.2,scale=1,size=400)
y2 = np.random.normal(loc=3.2,scale=1,size=400)
y3 = np.random.normal(loc=3.2,scale=1,size=400)
Z2 = np.vstack((y1,y2,y3)).T

y1 = np.random.normal(loc=4.4,scale=1,size=400)
y2 = np.random.normal(loc=4.4,scale=1,size=400)
y3 = np.random.normal(loc=4.4,scale=1,size=400)
Z3 = np.vstack((y1,y2,y3)).T

TOT = np.vstack((Z1,Z2,Z3))
#np.random.shuffle(TOT)
cat = np.concatenate((np.ones(400,dtype=int),2*np.ones(400,dtype=int),3*np.ones(400,dtype=int)),axis=0) # Classes des Z
TOT.shape
# Out:
# array([1, 1, 1, ..., 3, 3, 3])

# %% [markdown]
# On fait le graphique de l'inertie en fonction du nombre de classe que retourne l'algorithme du Kmeans.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

TOT_scal = StandardScaler().fit_transform(TOT)

inertia = []
inertia_scal = []

nb_clus = range(1,8)
for k in nb_clus:
    kmeanmodel = KMeans(n_clusters=k,max_iter=1000,n_init=50).fit(TOT)
    inertia.append(kmeanmodel.inertia_)
for k in nb_clus:
    kmeanmodel_scal = KMeans(n_clusters=k,max_iter=1000,n_init=50).fit(TOT)
    inertia_scal.append(kmeanmodel_scal.inertia_)

# %%
np.where( (inertia_scal == inertia) == False )
# On a les mêmes inerties pour des données qui ont été centrés, réduites; ce qui est normal comme on a des données 
# qui sont exprimées dans la même unité
# Out:
# (array([0]),)

# %%
plt.plot(nb_clus,inertia,'bx-')
plt.xlabel('Nombre de clusters')
plt.ylabel('Inertie')
plt.title("La méthode du coude utilisant l'inertie")
plt.show()

# %% [markdown]
# Le nombre de cluster optimum se situe au niveau du coude. On choisit 3. C'était prévisible, on avait simulé un ensemble de point à 3 classes.

# %% [markdown]
# # Exercice mélange de loi

# %% [markdown]
# 1/ Simuler un mélange de loi de taille 1000. Ce mélange de loi aura 3 lois. Chaque loi sera simulé par des vecteurs gaussiens de dimention 2. Les moyennes de ces classes sont respectivement (1,1), (3,3), (5,5). Les covarainces de ces 3 classes sont des matrices diagonales avec des 1. La probabilité d'apparition de ces classes est respectivement 1/4,1/4,1/2. Ce mélange deloi sera stocke dans MIX_DATA.

# %%
import numpy as np

p = np.random.choice(3,1000,p = (0.25,0.25,0.5))

loi1 = np.array([np.random.normal(1,1,size = len( np.where(p==0)[0] )), np.random.normal(1,1,size = len( np.where(p==0)[0] ))])
loi2 = np.array([np.random.normal(3,1,size = len( np.where(p==1)[0] )), np.random.normal(3,1,size = len( np.where(p==1)[0] ))])
loi3 = np.array([np.random.normal(5,1,size = len( np.where(p==2)[0] )), np.random.normal(5,1,size = len( np.where(p==2)[0] ))])
MIX_DATA = np.concatenate([loi1,loi2,loi3], axis = 1).T
MIX_DATA_NOT_SHUFFLE = np.copy(MIX_DATA)
np.random.shuffle(MIX_DATA)

# %%
MIX_DATA.shape
# Out:
# (1000, 2)

# %% [markdown]
# 2/ En vous inspirant de l'exemple ci_dessus appliquer la régle du coude pour déterminer le nombre de cluster optimum.

# %%
inertie = []
for k in range (1,8):
    kmeans = KMeans(n_clusters=k,max_iter=1000,n_init=50).fit(MIX_DATA)
    inertie.append(kmeans.inertia_)

plt.plot(range(1,8),inertie,'bx-')
plt.xlabel('Nombre de clusters')
plt.ylabel('Inertie')
plt.title("La méthode du coude utilisant l'inertie")
plt.show()   

print("On choisit 3 classes pour les kmeans")
# Out:
# On choisit 3 classes pour les kmeans

# %% [markdown]
# 3/ Fait un kmean à 3 classes sur les données MIX_DATA.

# %%
kmean = KMeans(n_clusters = 3, max_iter = 1000, n_init = 50).fit(MIX_DATA)
pred = kmean.labels_

# %% [markdown]
# 4/ Faite une représentation mettant en évidence les 3 classes. (on utilise pas le TSNE). Vous devez obtenir un graphique semblable à celui ci-dessous.

# %%
plt.scatter(loi1[0,:], loi1[1,:], label=1,lw=0.1)
plt.scatter(loi2[0,:], loi2[1,:], label=2,lw=0.1)
plt.scatter(loi3[0,:], loi3[1,:], label=3,lw=0.1)
plt.title('Classes Réelles')
# Out:
# Text(0.5,1,'Classes Réelles')

# %% [markdown]
# 5/Faite une représentation mettant en évidence les pattern produits par le modèle kmeans de la question 3.

# %%
for o in np.unique(pred):
    plt.scatter(MIX_DATA[:,0][pred==o], MIX_DATA[:, 1][pred==o], label=o,lw=0.1)
plt.legend(loc=3)
plt.title('Classes Prédites par les Kmeans')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# 6/ Faire classification hiérarchique à 3 classes. Représenter les données mettant en évidence les classes de la CAH.

# %%
CAH = AgglomerativeClustering(n_clusters=3, affinity='euclidean',linkage='ward')

cah = CAH.fit_predict(MIX_DATA) 
pred = cah

for o in np.unique(pred):
    plt.scatter(MIX_DATA[:,0][pred==o], MIX_DATA[:, 1][pred==o], label=o,lw=0.1)
plt.legend(loc=3)
plt.title('Classifiation CAH')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Exercice sur données lettres
# Dans cet exercice on va appliquer les algorithmes Kmeans et CAH sur des images représentants des lettres. Chaques image est modélisé par une matrice 28x28=784 pixels. Chaque pixel représente un niveau de gris. (dans le cas d'image en couleur on a 3 couche de pixel: une couche rouge, une couche verte, une couche bleu.

# %% [markdown]
#  1/ importation image : dataset
# * Pour importer les images et les transformer on objet numpy on utilise matplotlib.pyplot.imread.
# * Pour afficher une image on utilise matplotlib.pyplot.imread.imshow.
# * La fonction numpy.ravel() permet d'applatire un vecteur.
# Ci-dessous im1 représente l'image sous forme de matrice

# %%
import matplotlib.pyplot as plt
im1 = plt.imread('/users/legrad15/Documents/Data/imagekmeans/image1.png')
plt.imshow(im1, cmap='binary')
plt.show()

# %%
im1.shape
# Out:
# (28, 28)

# %% [markdown]
# Ici im1bis est le vecteur représentant l'image. Il vient de la matrice im1 que l'on a applati.

# %%
im1bis = im1.ravel()
im1bis.shape
# Out:
# (784,)

# %% [markdown]
# Vous devez télécharger les données suivantes: https://1drv.ms/u/s!Am09h0q2OIX0bzaaz8qoN9suO8U?e=KeVWxS. Ces données sont un ensembles de 2800 images environ. Il faut décompresser ce fichier et placer placer le résultat dans un répétoire vide image.

# %% [markdown]
# Transformer toutes les images du répétoire IMAGE en des vecteurs du type im1bis. Ensuite à partire de ces vecteurs faire une matrice dont chaque ligne est un vecteur de taille 784 représentant une image. Cette matrice sera stocke dans X_image_vect.

# %%
import os
images = os.listdir("/users/legrad15/Documents/Data/imagekmeans/")
images = [[plt.imread("/users/legrad15/Documents/Data/imagekmeans/" + o)] for o in images]

# %%
X_image_vect = [im[:][0].ravel() for im in images]
np.array(images_trans).shape
# Out:
# (2800, 784)

# %% [markdown]
# 2/Appliquer une regle du coude pour déterminer le nombre de classe optimum. Dans la suite on admettra que le nombre optimum de classe est 4. On oublira pas de mettre à l'echelle les données (StandardScaler()).

# %%
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(X_image_vect)
inertie = []
for k in range(1,8):
    kmean = KMeans(n_clusters=k,max_iter=1000,n_init = 50).fit(X_scaled)
    inertie.append(kmean.inertia_)
    
plt.plot(range(1,8),inertie,'bx-')
plt.xlabel('Nombre de clusters')
plt.ylabel('Inertie')
plt.title("La méthode du coude utilisant l'inertie")
plt.show()

# %% [markdown]
# On fait ensuite le graphe du coude:

# %% [markdown]
# 3/Représenter les données X_image_vect à l'aide dun TSNE à 2 composantes. On utilise les données X_image_vect.

# %%
t_sne = TSNE(n_components=2,random_state=1998)

X_proj = t_sne.fit_transform(X_image_vect)

plt.scatter( X_proj[:,0], X_proj[:,1] )

# %% [markdown]
# 4/Faite un kmeans dont le nombre de cluster est 4. Ce modele s'appelle kmean4. Il faut entrainer ce modele. Ensuite afficher kmean4.labels

# %%
kmean4 = KMeans(n_clusters=4,max_iter=1000,n_init = 50).fit(X_image_vect)

# %%
print(kmean4.labels_)
Y = kmean4.labels_
# Out:
# [2 1 1 ... 0 0 1]

# %% [markdown]
# 5/ Représenter les données avec leurs labels en utilisant un TSNE. Une couleur par label.

# %%
for k in range(0,4):
    plt.scatter( X_proj[:,0][Y==k], X_proj[:,1][Y==k], label = k )
plt.legend(loc=3)

# %% [markdown]
# 6/Afficher les données de 4 images ayant le label 0.

# %%
import numpy as np

X_image_vect = np.array(X_image_vect)
#ici on détecte les éléments yant pour label 0 
X_0 = X_image_vect[np.where(Y==0),:][0]
X_0_list = X_0.tolist()

#on reconstitue chaque matrice
X_0_list_image = [np.array(o).reshape(28,28) for o in X_0_list]

# %%
X_0_list_image[4].shape
# Out:
# (28, 28)

# %%
im1 = X_0_list_image[0]

import matplotlib.pyplot as plt
plt.imshow(im1, cmap='binary')
plt.show()

# %%
im2 = X_0_list_image[1]

import matplotlib.pyplot as plt
plt.imshow(im2, cmap='binary')
plt.show()

# %%
im2 = X_0_list_image[2]

import matplotlib.pyplot as plt
plt.imshow(im2, cmap='binary')
plt.show()

# %%
im2 = X_0_list_image[3]

import matplotlib.pyplot as plt
plt.imshow(im2, cmap='binary')
plt.show()

# %% [markdown]
# 7/Faite comme dans la quetion précédante mais pour la classe 3. Conclure.

# %%
X_3 = X_image_vect[np.where(Y==3),:][0]
X_3_list = X_3.tolist()

#on reconstitue chaque matrice
X_3_list_image = [np.array(o).reshape(28,28) for o in X_3_list]

# %%
im = X_3_list_image[0]

import matplotlib.pyplot as plt
plt.imshow(im, cmap='binary')
plt.show()

# %%
im = X_3_list_image[1]

import matplotlib.pyplot as plt
plt.imshow(im, cmap='binary')
plt.show()

# %%
im = X_3_list_image[2]

import matplotlib.pyplot as plt
plt.imshow(im, cmap='binary')
plt.show()

# %%
im = X_3_list_image[3]

import matplotlib.pyplot as plt
plt.imshow(im, cmap='binary')
plt.show()

# %% [markdown]
# On remarque que la justesse de prédiction n'est a priori (pour les 4 x 2 observations précédentes) pas la même pour les différentes classes.
# Ce n'est pas étonnant au vu du plot du TSNE en fonction des labels 0 à 3. On avait effectivement un chevauchement des classes notables pour les classes 0 et 1.
# A l'inverse, on avait graphiquement une classe bien définie pour la classe 3. Il en va de même pour la classe 2.
#
# On conclut donc que l'algo des kmeans pour notre problème semble pertienent pour différencié les classes 0 et donc, donc les caractères 'C' et 'A'.
# Cependant, l'algorithme est moins performant et ne parvient pas à distinguer les 'B' des 'D'.
#
# Ceci se comprend au vue de la forme de ces 2 lettres.
#
# Pour aller plus loin nous pourrions tenter de construire un réseau de neuronnes.
